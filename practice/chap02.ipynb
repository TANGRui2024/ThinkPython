# %%
# var
n = 3434

# %%
haha = 234234234

# %%
intro = " my name is haha "

# %%
intro
# Out:
# ' my name is haha '

# %%
n + 43243
# Out:
# 46677

# %%
2 * intro
# Out:
# ' my name is haha  my name is haha '

# %%
len(intro)
# Out:
# 17

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
# ...

# %%
import math
from diagram import make_binding, Frame

binding = make_binding("hello", " my name is haha ")
binding2 =  make_binding("d","12")

frame = Frame([binding, binding2])

# %%
from diagram import diagram, adjust


width, height, x, y = [3, 4, 1, 2]
ax = diagram(width, height)
bbox = frame.draw(ax, x, y, dy=-0.5)
# adjust(x, y, bbox)

# %%
millio!on = 1000000
# Out:
#   Cell In[45], line 1
#     millio!on = 1000000
#           ^
# SyntaxError: invalid syntax

# %%
76nasd = "gaga"
# Out:
#   Cell In[46], line 1
#     76nasd = "gaga"
#      ^
# SyntaxError: invalid decimal literal

# %%
from keyword import kwlist

len(kwlist)
# Out:
# 35

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(99)
# Out:
# 9.9498743710662

# %%
math.pow(3,3.3)
# Out:
# 37.540507598529544

# %%
34234+n+round(math.sqrt(99))*2
# Out:
# 37688

# %%
n + 5
# Out:
# 3439

# %%
print(n+10000)
print(n+1)
# Out:
# 13434
# 3435

# %%
print(intro, n)
# Out:
#  my name is haha  3434

# %%
#argument 
math.pow(5,2)
# Out:
# 25.0

# %%
int('101',2)
# Out:
# 5

# %%
round(math.pi,2)
# Out:
# 3.14

# %%
print('hello', 'do','you')
# Out:
# hello do you

# %%
#too much arguments
float('123',2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 #too much arguments
# ----> 2 float('123',2)
#
# TypeError: float expected at most 1 argument, got 2

# %%
#too few argument
math.pow(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 #too few argument
# ----> 2 math.pow(2)
#
# TypeError: pow expected 2 arguments, got 1

# %%
#tpye error
math.sqrt('234')
# Out:
# Failed to start the Kernel.
#
# ImportError: cannot import name 'StataKernel' from 'stata_kernel' (D:\App\Anaconda\Lib\site-packages\stata_kernel\__init__.py).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
