# %%
4554+4343
# Out:
# 8897

# %%
84 // 2
# Out:
# 42

# %%
7 ** 100
# Out:
# 3234476509624757991344647769100216810857203198904625400933895331391691459636928060001

# %%
round(545.6576785)
# Out:
# 546

# %%
abs(-42)
# Out:
# 42

# %%
'Hello'
# Out:
# 'Hello'

# %%
"world"
# Out:
# 'world'

# %%
"hello" + " my name is" + " AA"
# Out:
# 'hello my name is AA'

# %%
("hello" + " my name is" + " AA. ")*5
# Out:
# 'hello my name is AA. hello my name is AA. hello my name is AA. hello my name is AA. hello my name is AA. '

# %%
len('Hello my name is AA')
# Out:
# 19

# %%
type("hello")
# Out:
# str

# %%
type(23)
# Out:
# int

# %%
type(34.0)
# Out:
# float

# %%
int(34.0)
# Out:
# 34

# %%
float(34)
# Out:
# 34.0

# %%
int('234')/4
# Out:
# 58.5

# %%
int('234')//4
# Out:
# 58

# %%
1,000,000
# Out:
# (1, 0, 0)

# %%
1,00000000,0000
# Out:
# (1, 0, 0)

# %%
1_000_000
# Out:
# 1000000
